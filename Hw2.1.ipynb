# %%
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
url = "https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8"
table = pd.read_html(url, match='Коефіцієнт народжуваності в регіонах України', thousands=".", decimal=",")
df = pd.DataFrame(table[0])

# %%
## 1. Display the first rows of the table using the head method
df.head()
# Out:
#              Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0              Крим  23.0  20.6  16.0  13.0   7.3  12.6     —     —
# 1         Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2         Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3  Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4          Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2     —

# %%
## 2. Determine the number of rows and columns in the dataframe (shape attribute)
rows, columns = df.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")
# Out:
# Number of rows: 28
# Number of columns: 9

# %%
## 3. Replace the '—' values in the table with NaN values.
df.replace("—", np.nan, inplace=True)

# %%
## 4. Determine the types of all columns using dataframe.dtypespd.DataFrame(table[0].dtypes)
df.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990      float64
# 2000      float64
# 2012      float64
# 2014       object
# 2019       object
# dtype: object

# %%
## 5. Change the types of non-numeric columns to numeric. Hint - these are the columns where the '—' symbol was located.
df.astype({'2014': float, '2019': float})
df.dtypes
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990      float64
# 2000      float64
# 2012      float64
# 2014       object
# 2019       object
# dtype: object

# %%
## 6. Calculate the proportion of missing values in each column (use the isnull and sum methods).
calculate_null = df.isnull().sum()
print("\nNull values in column after sum\n", calculate_null)
# Out:
# Null values in column after sum
#  Регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 2000      0
# 2012      0
# 2014      2
# 2019      4
# dtype: int64

# %%
## 7. Delete the data for the entire country from the table, the last row of the table.
df.drop(df.index[-1], inplace=True)
print("Result\n", df)
# Out:
# Result
#                 Регіон  1950  1960  1970  1990  2000  2012  2014  2019
# 0                Крим  23.0  20.6  16.0  13.0   7.3  12.6   NaN   NaN
# 1           Вінницька  22.4  19.2  14.2  12.4   8.4  11.2  10.9   7.6
# 2           Волинська  24.7  25.0  17.9  15.3  11.2  14.8  14.1  10.1
# 3    Дніпропетровська  20.4  20.4  15.1  12.3   7.1  11.2  11.1   7.1
# 4            Донецька  27.1  21.4  14.0  10.9   6.1   9.8   8.2   NaN
# 5         Житомирська  26.1  22.3  15.9  12.9   8.9  12.2  12.0   7.9
# 6        Закарпатська  31.4  27.3  20.7  16.8  11.5  15.1  14.6  10.4
# 7          Запорізька  21.9  19.7  15.0  12.4   7.1  10.6  10.6   6.8
# 8   Івано-Франківська  24.3  24.8  18.2  15.5  10.3  12.4  12.2   8.8
# 9            Київська  20.4  18.9  15.6  12.3   7.3  12.2  12.1   8.0
# 10     Кіровоградська  21.6  17.1  14.5  12.6   7.9  11.0  10.8   6.8
# 11          Луганська  26.2  23.5  14.4  11.6   6.2   9.6   5.1   NaN
# 12          Львівська  23.4  24.0  17.1  14.0   9.1  11.9  11.9   8.7
# 13       Миколаївська  21.1  19.4  15.5  13.7   8.0  11.5  11.2   7.1
# 14            Одеська  24.1  19.2  14.8  12.6   8.0  12.7  12.3   8.8
# 15         Полтавська  18.6  16.3  13.1  11.8   7.0   9.9  10.0   6.5
# 16         Рівненська  26.9  26.7  19.3  15.8  11.8  15.9  14.8  10.7
# 17            Сумська  21.6  18.4  13.2  11.5   7.0   9.7   9.2   6.0
# 18      Тернопільська  21.3  21.6  15.7  14.2   9.2  11.3  10.9   7.6
# 19         Харківська  19.7  17.3  14.0  11.4   6.8   9.9  10.1   6.8
# 20         Херсонська  20.8  21.4  16.6  14.3   8.5  11.7  11.5   8.1
# 21        Хмельницька  23.4  19.8  14.8  12.9   8.5  11.3  11.2   7.9
# 22          Черкаська  20.5  17.9  14.4  12.3   7.5  10.0   9.8   6.4
# 23        Чернівецька  24.7  21.8  17.0  14.8  10.1  12.8  12.9   9.2
# 24       Чернігівська  22.0  18.3  12.7  10.8   6.9   9.4   9.0   6.1
# 25               Київ   NaN  17.4  15.9  12.0   7.3  12.0  12.1  11.0
# 26        Севастополь   NaN   NaN   NaN  12.5   7.0  12.0   NaN   NaN

# %%
## 8. Replace missing data in columns with the average values of these columns (using the fillna method).
df.drop('Регіон', axis=1).mean(numeric_only=True).round(0)
df.fillna(_, inplace=True)
df
# Out:
#                Регіон     1950     1960     1970  1990  2000  2012    2014  \
# 0                Крим     23.0     20.6     16.0  13.0   7.3  12.6  object
# 1           Вінницька     22.4     19.2     14.2  12.4   8.4  11.2    10.9
# 2           Волинська     24.7     25.0     17.9  15.3  11.2  14.8    14.1
# 3    Дніпропетровська     20.4     20.4     15.1  12.3   7.1  11.2    11.1
# 4            Донецька     27.1     21.4     14.0  10.9   6.1   9.8     8.2
# 5         Житомирська     26.1     22.3     15.9  12.9   8.9  12.2    12.0
# 6        Закарпатська     31.4     27.3     20.7  16.8  11.5  15.1    14.6
# 7          Запорізька     21.9     19.7     15.0  12.4   7.1  10.6    10.6
# 8   Івано-Франківська     24.3     24.8     18.2  15.5  10.3  12.4    12.2
# 9            Київська     20.4     18.9     15.6  12.3   7.3  12.2    12.1
# 10     Кіровоградська     21.6     17.1     14.5  12.6   7.9  11.0    10.8
# 11          Луганська     26.2     23.5     14.4  11.6   6.2   9.6     5.1
# 12          Львівська     23.4     24.0     17.1  14.0   9.1  11.9    11.9
# 13       Миколаївська     21.1     19.4     15.5  13.7   8.0  11.5    11.2
# 14            Одеська     24.1     19.2     14.8  12.6   8.0  12.7    12.3
# 15         Полтавська     18.6     16.3     13.1  11.8   7.0   9.9    10.0
# 16         Рівненська     26.9     26.7     19.3  15.8  11.8  15.9    14.8
# 17            Сумська     21.6     18.4     13.2  11.5   7.0   9.7     9.2
# 18      Тернопільська     21.3     21.6     15.7  14.2   9.2  11.3    10.9
# 19         Харківська     19.7     17.3     14.0  11.4   6.8   9.9    10.1
# 20         Херсонська     20.8     21.4     16.6  14.3   8.5  11.7    11.5
# 21        Хмельницька     23.4     19.8     14.8  12.9   8.5  11.3    11.2
# 22          Черкаська     20.5     17.9     14.4  12.3   7.5  10.0     9.8
# 23        Чернівецька     24.7     21.8     17.0  14.8  10.1  12.8    12.9
# 24       Чернігівська     22.0     18.3     12.7  10.8   6.9   9.4     9.0
# 25               Київ  float64     17.4     15.9  12.0   7.3  12.0    12.1
# 26        Севастополь  float64  float64  float64  12.5   7.0  12.0  object
#
#       2019
# 0   object
# 1      7.6
# 2     10.1
# 3      7.1
# 4   object
# 5      7.9
# 6     10.4
# 7      6.8
# 8      8.8
# 9      8.0
# 10     6.8
# 11  object
# 12     8.7
# 13     7.1
# 14     8.8
# 15     6.5
# 16    10.7
# 17     6.0
# 18     7.6
# 19     6.8
# 20     8.1
# 21     7.9
# 22     6.4
# 23     9.2
# 24     6.1
# 25    11.0
# 26  object

# %%
## 9. Get a list of regions where the birth rate in 2019 was higher than the average in Ukraine.
df['2019'] = pd.to_numeric(df['2019'], errors='coerce')
higher_birth_rate = df['2019'] > df['2019'].mean(numeric_only=True)
df[higher_birth_rate]['Регіон'].tolist()
# Out:
# ['Волинська',
#  'Закарпатська',
#  'Івано-Франківська',
#  'Львівська',
#  'Одеська',
#  'Рівненська',
#  'Херсонська',
#  'Чернівецька',
#  'Київ']

# %%
## 10. Which region had the highest birth rate in 2014?
df['2014'] = pd.to_numeric(df['2014'], errors='coerce')
region_with_highest_birth_rate_2014 = df.loc[df['2014'].idxmax(), 'Регіон']
print("Region with the highest birth rate in 2014:", region_with_highest_birth_rate_2014)
# Out:
# Region with the highest birth rate in 2014: Рівненська

# %%
## 11.  Create a bar chart of birth rates by region for the year 2019
plt.figure(figsize=(10, 6))
plt.barh(df['Регіон'], df['2019'], color='skyblue')
plt.xlabel('Birth Rate')
plt.ylabel('Region')
plt.title('Birth Rates by Region in Ukraine (2019)')
plt.show()

# %%
# Creating a line plot

region_data = df[df['Регіон'] == 'Донецька'].iloc[0, 1:]
years = df.columns[1:]

plt.figure(figsize=(10, 6))
plt.plot(years, region_data, color='blue', linestyle='-', linewidth=2)
plt.title('Birth Rate in Donetsk Oblast`')
plt.xlabel('Year')
plt.ylabel('Birth Rate')
plt.grid(True)
plt.show()

# %%
# Creating Bar plot

x = df['Регіон']
y = df['2000']

plt.figure(figsize=(10, 6))
sns.barplot(x=x, y=y, palette='coolwarm')
plt.title('Birth Rate in 2000')
plt.xlabel('Region')
plt.ylabel('Birth Rate')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# C:\Users\Grig\AppData\Local\Temp\ipykernel_5644\3077257112.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=x, y=y, palette='coolwarm')

# %%
# Scatter Plot

x = df['2019']
y = df['2000']

plt.figure(figsize=(10, 6))
plt.scatter(x=x, y=y)
plt.title('Birth Rate Comparison')
plt.xlabel('Birth Rate in 2019')
plt.ylabel('Birth Rate in 2000')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
# Pie chart

x = df['2012']
y = df['Регіон']

plt.figure(figsize=(10, 6))
plt.pie(x=x, labels=y, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Birth Rates by Region in 2012')
# Out:
# Text(0.5, 1.0, 'Proportion of Birth Rates by Region in 2012')
